# %% [markdown]
# Notebook based on "segmentation_example_keras" and "solution" notebooks
# the EMBL Machine Learning for Image Analysis Course 2018:
#
# Organisers
# Anna Kreshuk - EMBL, Vera Matser - EMBL EBI, Tobias Rasse - EMBL
#
# Trainers
# Thorsten Falk - Freiburg University
# Fred Hamprecht - Heidelberg University
# Anna Kreshuk - EMBL
# Constantin Pape - Heidelberg University
# Tobias Rasse - EMBL
# Pejman Rasti - Université d’Angers
# David Rousseau - Université d’Angers
# Martin Weigert - MPI-CBG
# Uwe Schmidt - MPI-CBG

# %% [markdown]
# modified by Tobias Rasse tobias.rasse@mpi-bn.mpg.de for use in OpSeF

# %% [markdown]
# ### Importing the needed libraries

# %%
import os
import random
import pandas as pd
from itertools import chain
import numpy as np
# h5py to read the data-set
import h5py
# matplotlob for plotting
import matplotlib.pyplot as plt
# tensorboard
from keras.callbacks import TensorBoard

import tensorflow as tf
import keras

from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalMaxPool2D
from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from keras.losses import categorical_crossentropy
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# Out:
# Using TensorFlow backend.
# /home/trasse/anaconda3/envs/opsef004/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/trasse/anaconda3/envs/opsef004/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/trasse/anaconda3/envs/opsef004/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/trasse/anaconda3/envs/opsef004/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/trasse/anaconda3/envs/opsef004/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/trasse/anaconda3/envs/opsef004/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import tifffile as tif

# %%
import inspect
import pickle
from glob import glob
import os
from csbdeep.utils import Path, normalize
from stardist import fill_label_holes, random_label_cmap, calculate_extents, gputools_available,_draw_polygons
from stardist.models import Config2D, StarDist2D, StarDistData2D
from tqdm import tqdm

# %%
import numpy as np
import matplotlib.pyplot as plt
import imageio
import skimage.segmentation
import skimage.morphology
import skimage.transform
from scipy.ndimage.morphology import binary_dilation

# %%
from keras.utils import to_categorical

# %% [markdown]
# ## Functions

# %%
def label_to_target(label, size_filter=25, boundary_width=2, for_pytorch=True):
    # next, label the annotations and remove small objects
    label = skimage.morphology.label(label)
    label = skimage.morphology.remove_small_objects(label, min_size=size_filter)
    # next, find boundaries and dilate them
    boundaries = skimage.segmentation.find_boundaries(label)
    boundaries = binary_dilation(boundaries, iterations=boundary_width)
    # the way we process the labels depends on the framework we are using.
    # for pytorch, we need labels with a single channel, where the values stand for:
    # 0: background
    # 1: inner cells
    # 2: cell boundaries
    if for_pytorch:
        label_out = np.zeros_like(label, dtype='int64')
        label_out[(label != 0) & (boundaries == 0)] = 1
        label_out[boundaries == 1] = 2
    
    # for keras we need three binary channels as labels:
    # channel 0: background
    # channel 1: inner cells
    # channel 2: cell boundaries
    else:
        label_out = np.zeros(label.shape + (3,), dtype='int64')
        label_out[(label == 0) & (boundaries == 0), 0] = 1.
        label_out[(label != 0) & (boundaries == 0), 1] = 1.
        label_out[boundaries == 1, 2] = 1.
    return label_out

# %% [markdown]
# ## Main Code

# %%
main_folder = os.path.dirname(os.path.abspath(inspect.stack()[0][1])).replace("TrainUNet","Augment")
file_path = "{}/my_runs/augment_settings_xl.pkl".format(main_folder)
infile = open(file_path,'rb')
parameter = pickle.load(infile)
print("Loading processing pipeline from",file_path)
infile.close()
aug_sets,pre_defined_pipelines,data_main_GT,Datasets_Download = parameter
# Out:
# Loading processing pipeline from /home/trasse/github/OpSeF-IV/Train/Augment/my_runs/augment_settings_xl.pkl

# %%
# define training settings
trainModelSettings = {}
trainModelSettings["root"] = data_main_GT
trainModelSettings["data"] = "DSB2018_FL_Nuc_Subset_Basic_Nuc_512"
trainModelSettings["path"] = os.path.join(trainModelSettings["root"],trainModelSettings["data"])

# %%
X = sorted(glob('{}/train/images/*.tif'.format(trainModelSettings["path"])))
Y = sorted(glob('{}/train/masks/*.tif'.format(trainModelSettings["path"])))
assert all(Path(x).name==Path(y).name for x,y in zip(X,Y))

# load data
X = list(map(tif.imread,X))
Y = list(map(tif.imread,Y))
n_channel = 1 if X[0].ndim == 2 else X[0].shape[-1]
    
# Normalize images and fill small label holes
axis_norm = (0,1)   # normalize channels independently
# axis_norm = (0,1,2) # normalize channels jointly

if n_channel > 1:
    print("Normalizing image channels %s." % ('jointly' if axis_norm is None or 2 in axis_norm else 'independently'))
    sys.stdout.flush()
X = [normalize(x,1,99.8,axis=axis_norm) for x in tqdm(X)]
Y = [fill_label_holes(y) for y in tqdm(Y)]
# Out:
# 100%|██████████| 693/693 [00:01<00:00, 400.27it/s]
# 100%|██████████| 693/693 [00:05<00:00, 126.83it/s]

# %% [markdown]
# ### Analyse label:
# Keras needs as input one label per class (e.g. background, boundary, cell).
# We currently have one label per cell.

# %%
# first have a look at the labels
plt.figure(figsize=(10,10))
plt.imshow(Y[0][:,:,0])
plt.show()

# %%
# and the data
plt.figure(figsize=(10,10))
plt.imshow(X[0][:,:])
plt.show()

# %%
print("There are ", len(np.unique(Y[0])), "unique label:",np.unique(Y[0]))
# Out:
# There are  148 unique label: [  0   8   9  10  11  12  13  14  15  17  19  20  22  26  30  31  33  37
#   41  42  43  44  47  48  50  52  55  58  59  62  63  65  66  70  76  77
#   79  86  88  89  90  94 100 102 104 105 106 107 108 109 110 111 112 114
#  115 119 122 125 129 133 136 137 138 140 143 144 145 150 151 152 153 156
#  157 166 171 172 177 178 181 182 184 187 188 189 190 192 195 197 198 199
#  200 202 203 204 206 209 210 211 212 213 217 219 222 225 227 229 233 235
#  237 238 242 243 244 245 247 248 251 252 256 257 259 260 262 265 267 268
#  270 272 273 274 277 281 284 285 287 289 290 293 294 296 297 298 299 300
#  303 304 307 308]

# %%
### Convert label
Y3 = [label_to_target(ll) for ll in Y]
# Out:
# /home/trasse/anaconda3/envs/opsef004/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   after removing the cwd from sys.path.

# %%
# first have a look at the labels
plt.figure(figsize=(10,10))
plt.imshow(Y3[0][:,:,0])
plt.show()

# %%
Y3binary = [to_categorical(img) for img in Y3]

# %%
i = 0

plt.figure(figsize=(15,4))
plt.subplot(131)  #sublot(Anzahl Zeilen Anzahl Spalten Bild Nummer)\
plt.imshow(Y3binary[i][:,:,0])
plt.colorbar()
plt.title('Binary 0')

plt.subplot(132)  #sublot(Anzahl Zeilen Anzahl Spalten Bild Nummer)\
plt.imshow(Y3binary[i][:,:,1])
plt.colorbar()
plt.title('Binary 1')

plt.subplot(133)  #sublot(Anzahl Zeilen Anzahl Spalten Bild Nummer)\
plt.imshow(Y3binary[i][:,:,2])
#plt.imshow(preds_train[i][:,:,0])
plt.colorbar()
plt.title('Binary 2')

plt.show()

# %%
Y3 = [img[:,:,2] for img in Y3binary]
Y3 = [img[:,:,None] for img in Y3]

# %%
print(Y3[1].shape)
# Out:
# (512, 512, 1)

# %%
# Split into train and validation datasets.
assert len(X) > 1, "not enough training data"
rng = np.random.RandomState(42)
ind = rng.permutation(len(X))
n_val = max(1, int(round(0.15 * len(ind))))
ind_train, ind_val = ind[:-n_val], ind[-n_val:]
X_val, Y_val = [X[i] for i in ind_val]  , [Y3[i] for i in ind_val]
X_trn, Y_trn = [X[i] for i in ind_train], [Y3[i] for i in ind_train] 
print('number of images: %3d' % len(X))
print('- training:       %3d' % len(X_trn))
print('- validation:     %3d' % len(X_val))
# Out:
# number of images: 693
# - training:       589
# - validation:     104

# %%
# add axis were needed and stack images

# train
X_trn_arr = np.stack([img[:,:,None] for img in X_trn])
print(X_trn_arr.shape)
Y_trn_arr = np.stack([img for img in Y_trn])
print(Y_trn_arr.shape)

# validate
X_val_arr = np.stack([img[:,:,None] for img in X_val])
print(X_val_arr.shape)
Y_val_arr = np.stack([img for img in Y_val])
print(Y_val_arr.shape)
# Out:
# (589, 512, 512, 1)
# (589, 512, 512, 1)
# (104, 512, 512, 1)
# (104, 512, 512, 1)

# %% [markdown]
# ## Define model

# %%
def dice_coefficient(y_true, y_pred):
    eps = 1e-6
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection) / (K.sum(y_true_f * y_true_f) + K.sum(y_pred_f * y_pred_f) + eps)

# %%
#Each block of u-net architecture consist of two Convolution layers
# These two layers are written in a function to make our code clean
def conv2d_block(input_tensor, n_filters, kernel_size=3):
    # first layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size),
               padding="same")(input_tensor)
    x = keras.layers.Activation("relu")(x)
    # second layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), 
               padding="same")(x)
    x = keras.layers.Activation("relu")(x)
    return x

# %%
# The u-net architecture consists of contracting and expansive paths which
# shrink and expands the inout image respectivly. 
# Output image have the same size of input image
def get_unet(input_img, n_filters):
    # contracting path
    c1 = conv2d_block(input_img, n_filters=n_filters*4, kernel_size=3) #The first block of U-net
    p1 = MaxPooling2D((2, 2)) (c1)

    c2 = conv2d_block(p1, n_filters=n_filters*8, kernel_size=3)
    p2 = MaxPooling2D((2, 2)) (c2)

    c3 = conv2d_block(p2, n_filters=n_filters*16, kernel_size=3)
    p3 = MaxPooling2D((2, 2)) (c3)

    c4 = conv2d_block(p3, n_filters=n_filters*32, kernel_size=3)
    p4 = MaxPooling2D(pool_size=(2, 2)) (c4)
    
    c5 = conv2d_block(p4, n_filters=n_filters*64, kernel_size=3)
    
    # expansive path
    u6 = Conv2DTranspose(n_filters*32, (3, 3), strides=(2, 2), padding='same') (c5)
    u6 = concatenate([u6, c4])
    c6 = conv2d_block(u6, n_filters=n_filters*32, kernel_size=3)

    u7 = Conv2DTranspose(n_filters*16, (3, 3), strides=(2, 2), padding='same') (c6)
    u7 = concatenate([u7, c3])
    c7 = conv2d_block(u7, n_filters=n_filters*16, kernel_size=3)

    u8 = Conv2DTranspose(n_filters*8, (3, 3), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c2])
    c8 = conv2d_block(u8, n_filters=n_filters*8, kernel_size=3)

    u9 = Conv2DTranspose(n_filters*4, (3, 3), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = conv2d_block(u9, n_filters=n_filters*4, kernel_size=3)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
input_img = Input((X_trn_arr.shape[1], X_trn_arr.shape[2], 1), name='img')

# %%
# Creating and Compiling the model

model = get_unet(input_img, n_filters=4)
model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=[dice_coefficient])

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                (None, 512, 512, 1)  0
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 512, 512, 16) 160         img[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 512, 512, 16) 0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 512, 512, 16) 2320        activation_37[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 512, 512, 16) 0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 256, 256, 16) 0           activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 256, 256, 32) 4640        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 256, 256, 32) 0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 256, 256, 32) 9248        activation_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 256, 256, 32) 0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 128, 128, 32) 0           activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 128, 128, 64) 18496       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 128, 128, 64) 0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 128, 128, 64) 36928       activation_41[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 128, 128, 64) 0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 64, 64, 64)   0           activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 64, 64, 128)  73856       max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 64, 64, 128)  0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 64, 64, 128)  147584      activation_43[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 64, 64, 128)  0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 32, 32, 128)  0           activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 32, 256)  295168      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 32, 32, 256)  0           conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 32, 32, 256)  590080      activation_45[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 32, 32, 256)  0           conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 64, 64, 128)  295040      activation_46[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 64, 64, 256)  0           conv2d_transpose_9[0][0]
#                                                                  activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 64, 64, 128)  295040      concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 64, 64, 128)  0           conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 64, 64, 128)  147584      activation_47[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 64, 64, 128)  0           conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 128, 128, 64) 73792       activation_48[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 128, 128, 128 0           conv2d_transpose_10[0][0]
#                                                                  activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 128, 128, 64) 73792       concatenate_10[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 128, 128, 64) 0           conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 128, 128, 64) 36928       activation_49[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 128, 128, 64) 0           conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 256, 256, 32) 18464       activation_50[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 256, 256, 64) 0           conv2d_transpose_11[0][0]
#                                                                  activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 256, 256, 32) 18464       concatenate_11[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 256, 256, 32) 0           conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 256, 256, 32) 9248        activation_51[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 256, 256, 32) 0           conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 512, 512, 16) 4624        activation_52[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 512, 512, 32) 0           conv2d_transpose_12[0][0]
#                                                                  activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 512, 512, 16) 4624        concatenate_12[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 512, 512, 16) 0           conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 512, 512, 16) 2320        activation_53[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 512, 512, 16) 0           conv2d_56[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 512, 512, 1)  17          activation_54[0][0]
# ==================================================================================================
# Total params: 2,158,417
# Trainable params: 2,158,417
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train model

# %%
# saving the log and show it by tensorboard
NAME='u-net'
tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

# %%
# Fiting the model 
results = model.fit(X_trn_arr, Y_trn_arr, batch_size=1, epochs=100, callbacks=[tensorboard],
                    validation_data=(X_val_arr, Y_val_arr))
# Out:
# Train on 589 samples, validate on 104 samples
# Epoch 1/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0865 - dice_coefficient: 0.8645 - val_loss: 0.0873 - val_dice_coefficient: 0.8660
# Epoch 2/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0869 - dice_coefficient: 0.8638 - val_loss: 0.0876 - val_dice_coefficient: 0.8641
# Epoch 3/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0858 - dice_coefficient: 0.8659 - val_loss: 0.0866 - val_dice_coefficient: 0.8613
# Epoch 4/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0857 - dice_coefficient: 0.8658 - val_loss: 0.0851 - val_dice_coefficient: 0.8643
# Epoch 5/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0851 - dice_coefficient: 0.8667 - val_loss: 0.0902 - val_dice_coefficient: 0.8569
# Epoch 6/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0839 - dice_coefficient: 0.8686 - val_loss: 0.0881 - val_dice_coefficient: 0.8599
# Epoch 7/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0831 - dice_coefficient: 0.8701 - val_loss: 0.0846 - val_dice_coefficient: 0.8684
# Epoch 8/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0831 - dice_coefficient: 0.8700 - val_loss: 0.0838 - val_dice_coefficient: 0.8681
# Epoch 9/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0827 - dice_coefficient: 0.8711 - val_loss: 0.0848 - val_dice_coefficient: 0.8643
# Epoch 10/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0826 - dice_coefficient: 0.8709 - val_loss: 0.0836 - val_dice_coefficient: 0.8700
# Epoch 11/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0811 - dice_coefficient: 0.8735 - val_loss: 0.0830 - val_dice_coefficient: 0.8720
# Epoch 12/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0824 - dice_coefficient: 0.8716 - val_loss: 0.0840 - val_dice_coefficient: 0.8702
# Epoch 13/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0813 - dice_coefficient: 0.8731 - val_loss: 0.0829 - val_dice_coefficient: 0.8671
# Epoch 14/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0798 - dice_coefficient: 0.8754 - val_loss: 0.0831 - val_dice_coefficient: 0.8702
# Epoch 15/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0795 - dice_coefficient: 0.8760 - val_loss: 0.0822 - val_dice_coefficient: 0.8741
# Epoch 16/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0797 - dice_coefficient: 0.8755 - val_loss: 0.0845 - val_dice_coefficient: 0.8689
# Epoch 17/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0788 - dice_coefficient: 0.8771 - val_loss: 0.0857 - val_dice_coefficient: 0.8686
# Epoch 18/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0786 - dice_coefficient: 0.8773 - val_loss: 0.0851 - val_dice_coefficient: 0.8693
# Epoch 19/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0780 - dice_coefficient: 0.8787 - val_loss: 0.0825 - val_dice_coefficient: 0.8727
# Epoch 20/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0783 - dice_coefficient: 0.8777 - val_loss: 0.0817 - val_dice_coefficient: 0.8750
# Epoch 21/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0772 - dice_coefficient: 0.8796 - val_loss: 0.0820 - val_dice_coefficient: 0.8718
# Epoch 22/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0770 - dice_coefficient: 0.8804 - val_loss: 0.0826 - val_dice_coefficient: 0.8735
# Epoch 23/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0778 - dice_coefficient: 0.8788 - val_loss: 0.0833 - val_dice_coefficient: 0.8696
# Epoch 24/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0759 - dice_coefficient: 0.8821 - val_loss: 0.0828 - val_dice_coefficient: 0.8722
# Epoch 25/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0756 - dice_coefficient: 0.8825 - val_loss: 0.0816 - val_dice_coefficient: 0.8766
# Epoch 26/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0753 - dice_coefficient: 0.8827 - val_loss: 0.0840 - val_dice_coefficient: 0.8727
# Epoch 27/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0750 - dice_coefficient: 0.8832 - val_loss: 0.0819 - val_dice_coefficient: 0.8756
# Epoch 28/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0752 - dice_coefficient: 0.8835 - val_loss: 0.0914 - val_dice_coefficient: 0.8512
# Epoch 29/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0758 - dice_coefficient: 0.8821 - val_loss: 0.0833 - val_dice_coefficient: 0.8712
# Epoch 30/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0741 - dice_coefficient: 0.8848 - val_loss: 0.0843 - val_dice_coefficient: 0.8713
# Epoch 31/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0739 - dice_coefficient: 0.8846 - val_loss: 0.0832 - val_dice_coefficient: 0.8693
# Epoch 32/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0738 - dice_coefficient: 0.8854 - val_loss: 0.0840 - val_dice_coefficient: 0.8747
# Epoch 33/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0733 - dice_coefficient: 0.8864 - val_loss: 0.0839 - val_dice_coefficient: 0.8762
# Epoch 34/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0733 - dice_coefficient: 0.8859 - val_loss: 0.0835 - val_dice_coefficient: 0.8755
# Epoch 35/100
# 589/589 [==============================] - 17s 29ms/step - loss: 0.0725 - dice_coefficient: 0.8874 - val_loss: 0.0835 - val_dice_coefficient: 0.8703
# Epoch 36/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0727 - dice_coefficient: 0.8873 - val_loss: 0.0839 - val_dice_coefficient: 0.8721
# Epoch 37/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0730 - dice_coefficient: 0.8857 - val_loss: 0.0852 - val_dice_coefficient: 0.8729
# Epoch 38/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0721 - dice_coefficient: 0.8884 - val_loss: 0.0841 - val_dice_coefficient: 0.8741
# Epoch 39/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0717 - dice_coefficient: 0.8886 - val_loss: 0.0842 - val_dice_coefficient: 0.8715
# Epoch 40/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0713 - dice_coefficient: 0.8893 - val_loss: 0.0851 - val_dice_coefficient: 0.8727
# Epoch 41/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0707 - dice_coefficient: 0.8902 - val_loss: 0.0838 - val_dice_coefficient: 0.8750
# Epoch 42/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0707 - dice_coefficient: 0.8904 - val_loss: 0.0849 - val_dice_coefficient: 0.8688
# Epoch 43/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0705 - dice_coefficient: 0.8908 - val_loss: 0.0838 - val_dice_coefficient: 0.8716
# Epoch 44/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0702 - dice_coefficient: 0.8910 - val_loss: 0.0849 - val_dice_coefficient: 0.8729
# Epoch 45/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0701 - dice_coefficient: 0.8914 - val_loss: 0.0873 - val_dice_coefficient: 0.8689
# Epoch 46/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0697 - dice_coefficient: 0.8921 - val_loss: 0.0856 - val_dice_coefficient: 0.8735
# Epoch 47/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0695 - dice_coefficient: 0.8924 - val_loss: 0.0858 - val_dice_coefficient: 0.8734
# Epoch 48/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0692 - dice_coefficient: 0.8928 - val_loss: 0.0859 - val_dice_coefficient: 0.8662
# Epoch 49/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0689 - dice_coefficient: 0.8934 - val_loss: 0.0853 - val_dice_coefficient: 0.8715
# Epoch 50/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0687 - dice_coefficient: 0.8934 - val_loss: 0.0887 - val_dice_coefficient: 0.8695
# Epoch 51/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0685 - dice_coefficient: 0.8937 - val_loss: 0.0884 - val_dice_coefficient: 0.8726
# Epoch 52/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0686 - dice_coefficient: 0.8938 - val_loss: 0.0869 - val_dice_coefficient: 0.8717
# Epoch 53/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0685 - dice_coefficient: 0.8938 - val_loss: 0.0856 - val_dice_coefficient: 0.8729
# Epoch 54/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0683 - dice_coefficient: 0.8945 - val_loss: 0.0891 - val_dice_coefficient: 0.8700
# Epoch 55/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0679 - dice_coefficient: 0.8946 - val_loss: 0.0855 - val_dice_coefficient: 0.8748
# Epoch 56/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0672 - dice_coefficient: 0.8961 - val_loss: 0.0862 - val_dice_coefficient: 0.8742
# Epoch 57/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0673 - dice_coefficient: 0.8961 - val_loss: 0.0865 - val_dice_coefficient: 0.8703
# Epoch 58/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0668 - dice_coefficient: 0.8965 - val_loss: 0.0868 - val_dice_coefficient: 0.8723
# Epoch 59/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0671 - dice_coefficient: 0.8964 - val_loss: 0.0868 - val_dice_coefficient: 0.8729
# Epoch 60/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0666 - dice_coefficient: 0.8971 - val_loss: 0.0872 - val_dice_coefficient: 0.8698
# Epoch 61/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0669 - dice_coefficient: 0.8969 - val_loss: 0.0876 - val_dice_coefficient: 0.8696
# Epoch 62/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0662 - dice_coefficient: 0.8978 - val_loss: 0.0880 - val_dice_coefficient: 0.8745
# Epoch 63/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0659 - dice_coefficient: 0.8983 - val_loss: 0.0909 - val_dice_coefficient: 0.8713
# Epoch 64/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0659 - dice_coefficient: 0.8984 - val_loss: 0.0906 - val_dice_coefficient: 0.8738
# Epoch 65/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0657 - dice_coefficient: 0.8985 - val_loss: 0.0898 - val_dice_coefficient: 0.8701
# Epoch 66/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0655 - dice_coefficient: 0.8989 - val_loss: 0.0928 - val_dice_coefficient: 0.8710
# Epoch 67/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0653 - dice_coefficient: 0.8992 - val_loss: 0.0893 - val_dice_coefficient: 0.8679
# Epoch 68/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0653 - dice_coefficient: 0.8993 - val_loss: 0.0893 - val_dice_coefficient: 0.8724
# Epoch 69/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0655 - dice_coefficient: 0.8993 - val_loss: 0.0893 - val_dice_coefficient: 0.8724
# Epoch 70/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0649 - dice_coefficient: 0.8999 - val_loss: 0.0889 - val_dice_coefficient: 0.8687
# Epoch 71/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0647 - dice_coefficient: 0.9005 - val_loss: 0.0869 - val_dice_coefficient: 0.8711
# Epoch 72/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0644 - dice_coefficient: 0.9009 - val_loss: 0.0889 - val_dice_coefficient: 0.8733
# Epoch 73/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0641 - dice_coefficient: 0.9013 - val_loss: 0.0899 - val_dice_coefficient: 0.8725
# Epoch 74/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0643 - dice_coefficient: 0.9012 - val_loss: 0.0900 - val_dice_coefficient: 0.8649
# Epoch 75/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0637 - dice_coefficient: 0.9021 - val_loss: 0.0890 - val_dice_coefficient: 0.8682
# Epoch 76/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0638 - dice_coefficient: 0.9019 - val_loss: 0.0898 - val_dice_coefficient: 0.8663
# Epoch 77/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0636 - dice_coefficient: 0.9022 - val_loss: 0.0903 - val_dice_coefficient: 0.8717
# Epoch 78/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0645 - dice_coefficient: 0.9005 - val_loss: 0.0878 - val_dice_coefficient: 0.8648
# Epoch 79/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0636 - dice_coefficient: 0.9021 - val_loss: 0.0927 - val_dice_coefficient: 0.8652
# Epoch 80/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0631 - dice_coefficient: 0.9028 - val_loss: 0.0918 - val_dice_coefficient: 0.8698
# Epoch 81/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0631 - dice_coefficient: 0.9028 - val_loss: 0.0872 - val_dice_coefficient: 0.8644
# Epoch 82/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0634 - dice_coefficient: 0.9024 - val_loss: 0.0906 - val_dice_coefficient: 0.8685
# Epoch 83/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0626 - dice_coefficient: 0.9039 - val_loss: 0.0890 - val_dice_coefficient: 0.8694
# Epoch 84/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0621 - dice_coefficient: 0.9045 - val_loss: 0.0928 - val_dice_coefficient: 0.8632
# Epoch 85/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0633 - dice_coefficient: 0.9024 - val_loss: 0.0915 - val_dice_coefficient: 0.8672
# Epoch 86/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0625 - dice_coefficient: 0.9040 - val_loss: 0.0901 - val_dice_coefficient: 0.8698
# Epoch 87/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0623 - dice_coefficient: 0.9043 - val_loss: 0.0915 - val_dice_coefficient: 0.8724
# Epoch 88/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0617 - dice_coefficient: 0.9055 - val_loss: 0.0906 - val_dice_coefficient: 0.8692
# Epoch 89/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0617 - dice_coefficient: 0.9055 - val_loss: 0.0911 - val_dice_coefficient: 0.8661
# Epoch 90/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0617 - dice_coefficient: 0.9052 - val_loss: 0.0918 - val_dice_coefficient: 0.8706
# Epoch 91/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0618 - dice_coefficient: 0.9053 - val_loss: 0.0923 - val_dice_coefficient: 0.8684
# Epoch 92/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0615 - dice_coefficient: 0.9055 - val_loss: 0.0910 - val_dice_coefficient: 0.8645
# Epoch 93/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0612 - dice_coefficient: 0.9057 - val_loss: 0.0904 - val_dice_coefficient: 0.8699
# Epoch 94/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0609 - dice_coefficient: 0.9065 - val_loss: 0.0924 - val_dice_coefficient: 0.8695
# Epoch 95/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0611 - dice_coefficient: 0.9065 - val_loss: 0.0929 - val_dice_coefficient: 0.8714
# Epoch 96/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0612 - dice_coefficient: 0.9061 - val_loss: 0.0958 - val_dice_coefficient: 0.8694
# Epoch 97/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0605 - dice_coefficient: 0.9070 - val_loss: 0.0945 - val_dice_coefficient: 0.8699
# Epoch 98/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0609 - dice_coefficient: 0.9066 - val_loss: 0.0910 - val_dice_coefficient: 0.8717
# Epoch 99/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0605 - dice_coefficient: 0.9074 - val_loss: 0.0960 - val_dice_coefficient: 0.8703
# Epoch 100/100
# 589/589 [==============================] - 17s 28ms/step - loss: 0.0607 - dice_coefficient: 0.9071 - val_loss: 0.0961 - val_dice_coefficient: 0.8634

# %%
## display results

# %%
klkl
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-e6c475293bfd> in <module>
# ----> 1 klkl
#
# NameError: name 'klkl' is not defined

# %%
preds_train = model.predict(X_trn_arr, verbose=1)
# Out:
# 589/589 [==============================] - 4s 7ms/step

# %%
preds_train_t = (preds_train > 0.5).astype(np.uint8)

# %%
preds_train_t[0].shape
# Out:
# (512, 512, 1)

# %%
i = 2

plt.figure(figsize=(15,4))
plt.subplot(131)  #sublot(Anzahl Zeilen Anzahl Spalten Bild Nummer)\
plt.imshow(X_trn_arr[i][:,:,0])
plt.colorbar()
plt.title('Input')

plt.subplot(132)  #sublot(Anzahl Zeilen Anzahl Spalten Bild Nummer)\
plt.imshow(Y_trn_arr[i][:,:,0])
plt.colorbar()
plt.title('Label')

plt.subplot(133)  #sublot(Anzahl Zeilen Anzahl Spalten Bild Nummer)\
plt.imshow(preds_train_t[i][:,:,0])
#plt.imshow(preds_train[i][:,:,0])
plt.colorbar()
plt.title('Prediction')

plt.show()

# %%
# first have a look at the labels
plt.figure(figsize=(10,10))
plt.imshow(preds_train_t[0][:,:,0])
plt.show()

# %%
# first have a look at the labels
plt.figure(figsize=(10,10))
plt.imshow(X_trn_arr[0][:,:,0])
plt.show()

# %%
# first have a look at the labels
plt.figure(figsize=(10,10))
plt.imshow(Y3[0][:,:,0])
plt.show()

# %%
# Predict on train, val and test
model = load_model('model-dsbowl2018-1.h5', custom_objects={'mean_iou': mean_iou})
preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True))

# %%
klkl

# %% [markdown]
# predictions = np.stack([predict_image(net, im) for im in test_images])

# %%
## keep for later

# %%
np.unique(train_labels[0]

# %%
print(trainModelSettings["path"])

# %%
print(X[0].shape)
if len(X[0].shape) == 2:
    IMG_HEIGHT, IMG_WIDTH = X[0].shape
    IMG_CHANNELS = 1
else:
    IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS = X[0].shape

# %%
print(Y[0].shape)

# %%
def to_array(img_list,IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS,my_datatype,add_axis = False):
    # convers list to array
    IMG_arr = np.zeros((len(img_list), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=my_datatype)
    for n in range(len(X_val)):
        if add_axis:
            IMG_arr[n,:,:,0] = img_list[n]
        else:
            IMG_arr[n,:,:,:] = img_list[n]
    return IMG_arr

# %%
# go from lists to arrays
X_trn_arr = to_array(X_trn,IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS,np.uint8,True)
Y_trn_arr = to_array(Y_trn,IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS,np.uint8)
X_val_arr = to_array(X_val,IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS,np.uint8,True)
Y_val_arr = to_array(Y_val,IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS,np.uint8)

# %%
# Fiting the model 
results = model.fit(X_trn_arr, Y_trn_arr, batch_size=1, epochs=2, callbacks=[tensorboard],
                    validation_data=(X_val_arr, Y_val_arr))

# %%
print(X_trn_arr.shape)

# %%
import keras

# %%
def dice_coefficient(y_true, y_pred):
    eps = 1e-6
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection) / (K.sum(y_true_f * y_true_f) + K.sum(y_pred_f * y_pred_f) + eps)

# %%
print

# %%
print(X[0].shape)
if len(X[0].shape) == 2:
    IMG_HEIGHT, IMG_WIDTH = X[0].shape
    IMG_CHANNELS = 1
else:
    IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS = X[0].shape

# %%
jkjkjk

# %% [markdown]
# ###  3. Creating the U-net model

# %% [markdown]
# ###  4. Training

# %%
trainModelSettings["epochs"] = 2
trainModelSettings["steps_per_epoch"] = 100

# %%
def to_array(img_list,IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS,my_datatype,add_axis = False):
    # convers list to array
    IMG_arr = np.zeros((len(img_list),1, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=my_datatype)
    for n in range(len(X_val)):
        if add_axis:
            IMG_arr[n,0,:,:,0] = img_list[n]
        else:
            IMG_arr[n,0,:,:,:] = img_list[n]
    return IMG_arr

# %%
# go from lists to arrays
X_trn_arr = to_array(X_trn,IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS,np.uint8,True)
Y_trn_arr = to_array(Y_trn,IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS,np.uint8)
X_val_arr = to_array(X_val,IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS,np.uint8,True)
Y_val_arr = to_array(Y_val,IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS,np.uint8)

# %%
print(X_trn_arr.shape)

# %%
#creating a training and validation generator that generate masks and images
train_generator = zip(X_trn_arr, Y_trn_arr)
val_generator = zip(X_val_arr, Y_val_arr)

# %%
# go from list to arrays
X_val_arr = np.zeros((len(X_val), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=my_datatype)
for n in range(len(X_val)):
    X_val_arr[n,:,:,0] = X_val[n]
Y_val_arr = np.zeros((len(Y_val), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
for n in range(len(X_val)):
    Y_val_arr[n,:,:,0] = Y_val[n]  

X_val_arr = np.zeros((len(X_val), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
for n in range(len(X_val)):
    X_val_arr[n,:,:,0] = X_val[n]
Y_val_arr = np.zeros((len(Y_val), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
for n in range(len(X_val)):
    Y_val_arr[n,:,:,0] = Y_val[n]

# %%
#creating a training and validation generator that generate masks and images
train_generator = zip(X_trn, Y_trn)
val_generator = zip(X_val, Y_val)

# %%
# Fit model
results = model.fit_generator(train_generator, validation_data=val_generator, validation_steps=10, steps_per_epoch=100,
                              epochs=3)

# %%
# Fit model
earlystopper = EarlyStopping(patience=3, verbose=1)
checkpointer = ModelCheckpoint('model-dsbowl2018-1.h5', verbose=1, save_best_only=True)
results = model.fit_generator(train_generator, validation_data=val_generator, validation_steps=10, steps_per_epoch=250,
                              epochs=3, callbacks=[earlystopper, checkpointer])

# %%
model.fit(X_trn, Y_trn, validation_data=(X_val,Y_val),
            epochs=trainModelSettings["epochs"] , steps_per_epoch=trainModelSettings["steps_per_epoch"])

# %%
    # train model
    model = StarDist2D(conf, name=trainModelSettings["name"], basedir = trainModelSettings["basedir_StarDist_Train"])
    median_size = calculate_extents(list(Y), np.median)
    fov = np.array(model._axes_tile_overlap('YX'))
    if any(median_size > fov):
        print("WARNING: median object size larger than field of view of the neural network.")
    model.train(X_trn, Y_trn, validation_data=(X_val,Y_val), augmenter=augmenter,
                epochs=trainModelSettings["epochs"] , steps_per_epoch=trainModelSettings["steps_per_epoch"])
    model.optimize_thresholds(X_val, Y_val)

# %% [markdown]
# ###  5. Prediction

# %%
# Predict on train, val and test
model = load_model('model-dsbowl2018-1.h5', custom_objects={'mean_iou': mean_iou})
preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True))

# %%
# Perform a sanity check on some random training samples
ix = random.randint(0, len(preds_train_t))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
imshow(np.squeeze(preds_train_t[ix]))
plt.show()

# %%
# Perform a sanity check on some random validation samples
ix = random.randint(0, len(preds_val_t))
imshow(X_train[int(X_train.shape[0]*0.9):][ix])
plt.show()
imshow(np.squeeze(Y_train[int(Y_train.shape[0]*0.9):][ix]))
plt.show()
imshow(np.squeeze(preds_val_t[ix]))
plt.show()

# %%
# Run-length encoding stolen from https://www.kaggle.com/rakhlin/fast-run-length-encoding-python
def rle_encoding(x):
    dots = np.where(x.T.flatten() == 1)[0]
    run_lengths = []
    prev = -2
    for b in dots:
        if (b>prev+1): run_lengths.extend((b + 1, 0))
        run_lengths[-1] += 1
        prev = b
    return run_lengths

def prob_to_rles(x, cutoff=0.5):
    lab_img = label(x > cutoff)
    for i in range(1, lab_img.max() + 1):
        yield rle_encoding(lab_img == i)

# %%
new_test_ids = []
rles = []
for n, id_ in enumerate(test_ids):
    rle = list(prob_to_rles(preds_test_upsampled[n]))
    rles.extend(rle)
    new_test_ids.extend([id_] * len(rle))
